# %%
df_datas_1 = spark.createDataFrame(["2021-07-05T10:00:00.000+0000","2022-12-05T00:09:00.000+0000","2017-02-23T16:23:00.000+0000"],"string").toDF("datas")
df_datas_2 = spark.createDataFrame(["2021-07-05 10:00","2022-12-05 00:09","2017-02-23 16:23"],"string").toDF("datas")
df_datas_3 = spark.createDataFrame(["05/07/2021","05/12/2020","23/02/2017"],"string").toDF("datas")
df_datas_4 = spark.createDataFrame(["05/07/2021 10:30","05/12/2020 14:15","23/02/2017 20:00"],"string").toDF("datas")

display(df_datas_1)
display(df_datas_2)
display(df_datas_3)
display(df_datas_4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>datas</th></tr></thead><tbody><tr><td>2021-07-05T10:00:00.000+0000</td></tr><tr><td>2022-12-05T00:09:00.000+0000</td></tr><tr><td>2017-02-23T16:23:00.000+0000</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_datas_1.createOrReplaceTempView("datas_1")
df_datas_2.createOrReplaceTempView("datas_2")
df_datas_3.createOrReplaceTempView("datas_3")
df_datas_4.createOrReplaceTempView("datas_4")

# %%
# %sql
/*Transformar somente DATA -> CAST(xxx as date)*/
select
  cast(datas as date)
from datas_1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>datas</th></tr></thead><tbody><tr><td>2021-07-05</td></tr><tr><td>2022-12-05</td></tr><tr><td>2017-02-23</td></tr></tbody></table></div>

# %%
# %sql
/*Transformar DATA e HORA -> TO_TIMESTAMP(#DF) 
 # -> onde o DF é o xxx - contido no to_DF("xxx") declarado*/

select
  TO_TIMESTAMP(datas) DATAS
from datas_1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DATAS</th></tr></thead><tbody><tr><td>2021-07-05T10:00:00.000+0000</td></tr><tr><td>2022-12-05T00:09:00.000+0000</td></tr><tr><td>2017-02-23T16:23:00.000+0000</td></tr></tbody></table></div>

# %%
df_datas_sql = spark.sql("""
 select TO_TIMESTAMP(datas)
 from datas_1
""")

display(df_datas_sql)

df_datas_sql2 = spark.sql("""
    select
    cast(datas as date)
    from datas_2
""")

display(df_datas_sql2)

df_datas_sql3 = spark.sql("""
    select
    to_date(datas, "dd/MM/yyyy")
    from datas_3
""")

display(df_datas_sql3)

df_datas_sql4 = spark.sql("""
    select
    to_date(datas, "dd/MM/yyyy HH:mm")
    from datas_4
""")

display(df_datas_sql3)

df_datas_sql.printSchema()
df_datas_sql2.printSchema()
df_datas_sql3.printSchema()
# Out:
# root
#  |-- to_timestamp(datas): timestamp (nullable = true)
#
# root
#  |-- datas: date (nullable = true)
#
# root
#  |-- to_date(datas, dd/MM/yyyy): date (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>to_timestamp(datas)</th></tr></thead><tbody><tr><td>2021-07-05T10:00:00.000+0000</td></tr><tr><td>2022-12-05T00:09:00.000+0000</td></tr><tr><td>2017-02-23T16:23:00.000+0000</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
# ...

# %%
from pyspark.sql.functions import *

df_datas_pyspark1 = df_datas_1
df_datas_pyspark1 = df_datas_pyspark.withColumn(
    "datas",to_timestamp("datas")
)

display(df_datas_pyspark1)

df_datas_pyspark2 = df_datas_2
df_datas_pyspark2 = df_datas_pyspark2.withColumn(
    "datas", to_date("datas")
)

display(df_datas_pyspark2)

df_datas_pyspark3 = df_datas_3
df_datas_pyspark3 = df_datas_pyspark3.withColumn(
    "datas", to_date("datas","dd/MM/yyyy")
)

display(df_datas_pyspark3)

df_datas_pyspark4 = df_datas_4
df_datas_pyspark4 = df_datas_pyspark4.withColumn(
    "datas", to_timestamp("datas","dd/MM/yyyy HH:mm")
)

display(df_datas_pyspark4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>datas</th></tr></thead><tbody><tr><td>2021-07-05T10:00:00.000+0000</td></tr><tr><td>2022-12-05T00:09:00.000+0000</td></tr><tr><td>2017-02-23T16:23:00.000+0000</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
